# %%
import pandas as pd

# %%
df = pd.read_csv('patient_data.csv')

# %%
df.columns
# Out:
# Index(['PatientID', 'Gender', 'Age', 'Age_Group', 'Age_TBI', 'Days_From1stTBI',
#        'Date of Injury', 'Type of Injury Code', 'EncounterID',
#        'Encounter_date', 'Encounter_Source', 'Provider_Specialty',
#        'Provider_type', 'Product_Line', 'TBI_encounter_flag',
#        'WarRelated_flag', 'PRE_max_days', 'POST_max_days', 'Stress', 'PTSD',
#        'Speech', 'Anxiety', 'Depression', 'Headache', 'Sleep', 'Audiology',
#        'Vision', 'Neurologic', 'Alzheimer', 'Cognitive', 'PCS', 'Endocrine',
#        'Skull_inj', 'NON_skull_inj'],
#       dtype='object')

# %%
df.drop(df.columns[[1,2,3,4,7,10,11,12,13,14,15,16,17]], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['PatientID', 'Days_From1stTBI', 'Date of Injury', 'EncounterID',
#        'Encounter_date', 'Stress', 'PTSD', 'Speech', 'Anxiety', 'Depression',
#        'Headache', 'Sleep', 'Audiology', 'Vision', 'Neurologic', 'Alzheimer',
#        'Cognitive', 'PCS', 'Endocrine', 'Skull_inj', 'NON_skull_inj'],
#       dtype='object')

# %%
df = df[(df.Stress > 0) | (df.PTSD > 0) | (df.Speech > 0) | (df.Anxiety > 0) | (df.Depression > 0) | (df.Headache > 0) | (df.Sleep > 0) | (df.Audiology > 0) | (df.Vision > 0) | (df.Neurologic > 0) | (df.Alzheimer > 0) | (df.Cognitive > 0) | (df.PCS > 0) | (df.Endocrine > 0)]

# %%
df.head()
# Out:
#     PatientID  Days_From1stTBI Date of Injury  EncounterID Encounter_date  \
# 23     382268            -1847     2013-10-15    512995337     2008-09-24
# 39     382268            -1707     2013-10-15    631038974     2009-02-11
# 41     382268            -1706     2013-10-15    628297420     2009-02-12
# 44     382268            -1693     2013-10-15    629663953     2009-02-25
# 46     382268            -1678     2013-10-15    653055765     2009-03-12
#
#     Stress  PTSD  Speech  Anxiety  Depression      ...        Sleep  \
# 23       0     0       0        0           0      ...            0
# 39       0     0       0        0           0      ...            0
# 41       0     0       0        0           0      ...            0
# 44       0     0       0        0           0      ...            0
# 46       0     0       0        0           0      ...            0
#
#     Audiology  Vision  Neurologic  Alzheimer  Cognitive  PCS  Endocrine  \
# ...

# %%
df.drop(['Skull_inj', 'NON_skull_inj'], axis=1, inplace=True)
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df
# Out:
#       PatientID  Days_From1stTBI Date of Injury  EncounterID Encounter_date  \
# 23       382268            -1847     2013-10-15    512995337     2008-09-24
# 39       382268            -1707     2013-10-15    631038974     2009-02-11
# 41       382268            -1706     2013-10-15    628297420     2009-02-12
# 44       382268            -1693     2013-10-15    629663953     2009-02-25
# 46       382268            -1678     2013-10-15    653055765     2009-03-12
# 47       382268            -1677     2013-10-15    654024147     2009-03-13
# 48       382268            -1673     2013-10-15    652262110     2009-03-17
# 49       382268            -1673     2013-10-15    652219062     2009-03-17
# 50       382268            -1665     2013-10-15    654048722     2009-03-25
# 51       382268            -1665     2013-10-15    653545948     2009-03-25
# 52       382268            -1656     2013-10-15    681979715     2009-04-03
# ...

# %%
df = df.drop(df.columns[[2,3,4]], axis=1)

# %%
df
# Out:
#       PatientID  Days_From1stTBI  Stress  PTSD  Speech  Anxiety  Depression  \
# 23       382268            -1847       0     0       0        0           0
# 39       382268            -1707       0     0       0        0           0
# 41       382268            -1706       0     0       0        0           0
# 44       382268            -1693       0     0       0        0           0
# 46       382268            -1678       0     0       0        0           0
# 47       382268            -1677       0     0       0        0           0
# 48       382268            -1673       0     0       0        0           0
# 49       382268            -1673       0     0       0        0           0
# 50       382268            -1665       0     0       0        0           0
# 51       382268            -1665       0     0       0        0           0
# 52       382268            -1656       0     0       0        0           0
# ...

# %%
df.to_csv('processed_data.csv')
